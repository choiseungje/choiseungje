# %% [markdown]
# <a href="https://colab.research.google.com/github/choiseungje/choiseungje/blob/main/202401852_%EC%B5%9C%EC%8A%B9%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 프로젝트 이름: 폭염과 범죄
#
# 제안자:202401852,최승제
#
# 1. 데이터셋 소개 및 분석 목적:
#
#   데이터셋1:폭염 데이터셋
#
#   데이터셋2: 경찰청_범죄 발생 장소별 통계 데이터셋
# 2.  데이터셋 분석 방법:
#
#   데이터전처리:그래프(x: 0.72(기온+습구온도)+40.6
#   ,y: 범죄율)를 만들것이다
#
#   데이터 시각화:히스토그램 또는 선형 그래프로 시각화 할 것이다.
#
#   데이터 분석: 가능한 범위 내에서 진행함
# 3. 예상결과:
#
#   가설: 기온과 습도가 오를수록 범죄 발생율이 증가 할 것이다.
#
#   예상결과: 그래프가 상승선을 탈 것이다.
# 4. 일정 계획:
#
#   데이터 수집 및 전처리: 5월 20일 ~ 6월 5일
#   데이터 시각화 및 분석: 5월 20일 ~ 6월 5일
#   보고서 작성: 5월 20일 ~ 6월 5일
